# %%
import pandas as pd
import numpy as np
import randominfo as ri
from faker import Faker
fake = Faker()
import random_address
from geopy.geocoders import Nominatim
# Using Nominatim Api
geolocator = Nominatim(user_agent="data")

# %%
sid = []
batch = []
stream=[]

x_perc = []
xii_perc = []
cet_perc = []
physics_xii = []
chem_xii = []
maths_xii = []
jee_perc = []

name = []
mob_no = []
email = []
gender = []
quota = []

father_name = []
father_occupation = []
mother_name = []
mother_occupation = []
parent_industry = []
parent_income = []

pincode = []
medical_history = []
area_name = []
landmark = []
city = []
state = []
nearest_rstation = []

# %%
industries = ['public administrative services', 'finance and real estate services', 'trade transport and hotels','information technology','agriculture and forestry', 'manufacturing','communications','constructions']
quota_type = ['minority', 'non-minority']
year = 2016
for _ in range(240) :
    #academic data☑️
    #generates percentage rounded upto 2 decimals
    x_perc.append(round(np.random.uniform(35.0, 100.0),2))
    xii_perc.append(round(np.random.uniform(51.0, 100.0),2))
    cet_perc.append(round(np.random.uniform(0.0, 100.0),2))    
    physics_xii.append(round(np.random.uniform(50.0, 100.0),2))
    chem_xii.append(round(np.random.uniform(50.0, 100.0),2))
    maths_xii.append(round(np.random.uniform(50.0, 100.0),2))
    jee_perc.append(round(np.random.uniform(0.0, 90.0),2))     
    
    #personal_data☑️
    gender.append(np.random.choice(('M','F','Rather not say'), p=(0.7,0.299,0.001)))
    #name.append(fake.name())
    #mob_no.append(fake.mob_no())
    email.append(np.random.choice(('@gmail.com','@yahoo.com','@hotmail.com'), p=(0.7,0.2,0.1)))
    quota.append(np.random.choice(quota_type))
    
    #parent_data☑️
    father_name.append(fake.name_male())
    father_occupation.append(fake.job())
    mother_name.append(fake.name_female())
    mother_occupation.append(fake.job())
    parent_income.append(np.random.randint(100000,1500000))
    parent_industry.append(np.random.choice(industries))
    
    #misc☑️
    pincode.append(np.random.randint(400001,400103))
    batch.append(year)
    #medical_history.append()

# %%
print(gender)
print(batch)
print(email)
print(quota)
print(father_name)
print(father_occupation)
print(mother_name)
print(mother_occupation)
print(parent_industry)
print(parent_income)
#print(medical_history)
print(pincode)
# Out:
# ['M', 'F', 'F', 'F', 'M', 'M', 'F', 'F', 'F', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'M', 'F', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'M', 'F', 'M', 'M', 'F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M', 'F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'F', 'M', 'M', 'F', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'F', 'F', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'F', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'F', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'M', 'F', 'M', 'M', 'F', 'F', 'F
# ...

# %%
#name generator
for i in range(0, len(gender)):
    
    if gender[i]== 'M':
        name.append(fake.name_male())
    elif gender[i] == 'F' :
        name.append(fake.name_female())
    else : 
        name.append(fake.name_nonbinary())
    
print(name)
# Out:
# ['Jason Payne', 'Susan Pearson', 'Michelle Hood', 'Brenda Phillips', 'Kenneth Wagner', 'Jacob Blackwell', 'Hannah Moore', 'Tammy Johnson', 'Anne Jackson', 'Tim Valencia', 'Jeremy Moyer', 'Katrina Rosales', 'Don Nichols', 'Justin Rollins', 'Dale Nelson', 'Francisco Taylor', 'Kelly Weaver', 'Robert Smith', 'Nicholas Williams Jr.', 'Eric Smith', 'Mr. Robert Cruz', 'Angela Barry', 'Carlos Shaw', 'James Campbell', 'Tristan Collier', 'Nicholas Williams', 'Allison Wilson', 'Scott Wilkerson', 'Julia Moon', 'Aaron Brown', 'Rebecca Griffin', 'Patrick Herman', 'Stephanie Anderson', 'Keith Fischer', 'Claudia White', 'Adam Lee', 'Kyle Long', 'April Aguilar', 'James Johnson', 'Matthew Miller', 'Cindy Stevens', 'Gregory Ramos', 'John Washington', 'Dustin Kemp', 'Stephen Williams', 'Jacob Alvarez', 'Joseph Henry', 'Joseph Davis', 'Barry Doyle', 'Matthew Horton', 'Austin Jones', 'Brian Wang', 'Christina Bailey', 'Christina Bryant', 'Juan Figueroa', 'Ryan Woodard', 'Jennifer Maldonado', 'Cody Edwards'
# ...

# %%
#email genrator
names = name.copy()
print(names)
j=0
for j in range(0,len(gender)):
    
    i = names[j] 
    names[j] = i.lower().replace(" ","") + email[j]
    
print(names)
# Out:
# ['Jason Payne', 'Susan Pearson', 'Michelle Hood', 'Brenda Phillips', 'Kenneth Wagner', 'Jacob Blackwell', 'Hannah Moore', 'Tammy Johnson', 'Anne Jackson', 'Tim Valencia', 'Jeremy Moyer', 'Katrina Rosales', 'Don Nichols', 'Justin Rollins', 'Dale Nelson', 'Francisco Taylor', 'Kelly Weaver', 'Robert Smith', 'Nicholas Williams Jr.', 'Eric Smith', 'Mr. Robert Cruz', 'Angela Barry', 'Carlos Shaw', 'James Campbell', 'Tristan Collier', 'Nicholas Williams', 'Allison Wilson', 'Scott Wilkerson', 'Julia Moon', 'Aaron Brown', 'Rebecca Griffin', 'Patrick Herman', 'Stephanie Anderson', 'Keith Fischer', 'Claudia White', 'Adam Lee', 'Kyle Long', 'April Aguilar', 'James Johnson', 'Matthew Miller', 'Cindy Stevens', 'Gregory Ramos', 'John Washington', 'Dustin Kemp', 'Stephen Williams', 'Jacob Alvarez', 'Joseph Henry', 'Joseph Davis', 'Barry Doyle', 'Matthew Horton', 'Austin Jones', 'Brian Wang', 'Christina Bailey', 'Christina Bryant', 'Juan Figueroa', 'Ryan Woodard', 'Jennifer Maldonado', 'Cody Edwards'
# ...

# %%
#mobile no generator
start = [77380, 84510, 84520, 84540, 90040, 96650, 98670, 98920, 99670, 99870, 77381, 90041, 96651, 98671, 98921, 99671, 99871, 77382, 90042, 96652, 98672, 98922, 99672, 99872, 77383, 90043, 96653, 98673, 98923, 99673, 99873, 77384, 90044, 96654, 98674, 98924, 99674, 99874, 77385, 90045, 96655, 98675, 98925, 99675, 99875, 77386, 90046, 96656, 98676, 98926, 99676, 99876, 77387, 90047, 96657, 98677, 98927, 99677, 99877, 77388, 84518, 84528, 84548, 90048, 96658, 98678, 98928, 99678, 99878, 77389, 84509, 84519, 84529, 84549, 90049, 96659, 98679, 98929, 99679, 99879, 89990, 89991, 89992, 89993, 89994, 89995, 89996, 89997, 89998, 89999]
for i in range(0, len(gender)):
    mob_no.append(str(np.random.choice(start)) + str(np.random.randint(10000,99999)))
    
print(mob_no)
# Out:
# ['8999815403', '9867053450', '7738214023', '9892020548', '9004612820', '9967480788', '8999541259', '9665586958', '9892999767', '7738047763', '9004533311', '7738045187', '9867835776', '8454961937', '7738817949', '9987555131', '9987936106', '8999670899', '8999919097', '9867357797', '8451887436', '9665768104', '8999148965', '7738092149', '7738961629', '8999450116', '8452812320', '9987627249', '9867554431', '8452971029', '8452988718', '9867494102', '9967625002', '9867631732', '9665398167', '9967399021', '9967147475', '9665410788', '9987449767', '9867775067', '9867333020', '9987993827', '7738536620', '9967467457', '8999579459', '7738089674', '9987464075', '9892034863', '9987132579', '8999585655', '8451936865', '8999972567', '9967631729', '9892931159', '8452855365', '7738929333', '8452840057', '9665297060', '9004222947', '9665850373', '8999428118', '9867029221', '8999859167', '7738611690', '8999040383', '9004979104', '9004151882', '7738179234', '8454850552', '9665283636', '9967024982', '84
# ...

# %%
# # landmark = []
# location = ri.get_address()
# # for j in range(0,len(gender)):
# #     location = random_address.real_random_address_by_postal_code(str(pincode[j]))
# #     landmark.append(location)
# print(location)
# address = fake.address().replace('\n', ' ') + ' ' + str(pincode[1])

# print(address)

# %%
id_no=1
for i in range(0, len(gender)):
    choice = stream.append(np.random.choice(('IT','COMPS','EXTC', 'MECH'), p=(0.25,0.25,0.25,0.25)))
    year = "2016"
    if choice == 'IT':
        rec = year + "1300"
    if choice == 'COMPS':
        rec = year + "1400"
    if choice == 'EXTC':
        rec = year + "1200"
    else :
        rec = year + "1100"
    if id_no < 10 :
        num = "00" + str(id_no)
    elif id_no < 100 :
        num = "0" + str(id_no)
    else :
        num = str(id_no)
    rec = rec + num
    id_no += 1
    sid.append(rec)
print(stream)
print(sid)
# Out:
# ['EXTC', 'COMPS', 'IT', 'COMPS', 'MECH', 'COMPS', 'COMPS', 'MECH', 'EXTC', 'EXTC', 'EXTC', 'EXTC', 'COMPS', 'IT', 'EXTC', 'EXTC', 'IT', 'IT', 'IT', 'EXTC', 'IT', 'IT', 'MECH', 'MECH', 'EXTC', 'MECH', 'COMPS', 'IT', 'EXTC', 'COMPS', 'EXTC', 'IT', 'IT', 'MECH', 'COMPS', 'COMPS', 'MECH', 'COMPS', 'COMPS', 'IT', 'EXTC', 'IT', 'IT', 'MECH', 'EXTC', 'MECH', 'EXTC', 'EXTC', 'EXTC', 'EXTC', 'COMPS', 'EXTC', 'MECH', 'EXTC', 'COMPS', 'EXTC', 'IT', 'MECH', 'MECH', 'EXTC', 'COMPS', 'COMPS', 'IT', 'COMPS', 'IT', 'IT', 'EXTC', 'COMPS', 'COMPS', 'EXTC', 'EXTC', 'COMPS', 'IT', 'MECH', 'EXTC', 'MECH', 'MECH', 'COMPS', 'EXTC', 'IT', 'MECH', 'MECH', 'MECH', 'COMPS', 'IT', 'MECH', 'EXTC', 'COMPS', 'COMPS', 'IT', 'IT', 'IT', 'IT', 'EXTC', 'COMPS', 'MECH', 'EXTC', 'EXTC', 'IT', 'IT', 'IT', 'IT', 'IT', 'MECH', 'EXTC', 'EXTC', 'IT', 'EXTC', 'COMPS', 'IT', 'COMPS', 'EXTC', 'IT', 'MECH', 'IT', 'COMPS', 'EXTC', 'MECH', 'IT', 'COMPS', 'MECH', 'MECH', 'MECH', 'IT', 'IT', 'IT', 'EXTC', 'IT', 'IT', 'MECH', 'MECH',
# ...

# %%
academic_data = pd.DataFrame(zip(sid,batch,stream,name,mob_no,names,gender,quota,x_perc,xii_perc,cet_perc,physics_xii,chem_xii,maths_xii,jee_perc,father_name,father_occupation,mother_name,mother_occupation,parent_industry,parent_income,pincode),columns=['sid','year','stream','name','mob_no','email','gender','quota','x_perc','xii_perc','cet_perc','physics_xii','chem_xii','maths_xii','jee_perc','father_name','father_occupation','mother_name','mother_occupation','sector','parent_income','pincode'])
academic_data
# Out:
#              sid  year stream             name      mob_no  \
# 0    20161100001  2016   EXTC      Jason Payne  8999815403
# 1    20161100002  2016  COMPS    Susan Pearson  9867053450
# 2    20161100003  2016     IT    Michelle Hood  7738214023
# 3    20161100004  2016  COMPS  Brenda Phillips  9892020548
# 4    20161100005  2016   MECH   Kenneth Wagner  9004612820
# ..           ...   ...    ...              ...         ...
# 235  20161100236  2016  COMPS  Jesse Rodriguez  9967492849
# 236  20161100237  2016  COMPS  Elizabeth Mckee  9967346519
# 237  20161100238  2016     IT    Shawna Nelson  9004729268
# 238  20161100239  2016   MECH      John Rivera  8451927079
# 239  20161100240  2016   EXTC      Curtis Park  7738492141
#
#                           email gender         quota  x_perc  xii_perc  ...  \
# 0          jasonpayne@gmail.com      M      minority   48.43     76.95  ...
# 1      susanpearson@hotmail.com      F  non-minority   65.99     95.02  ...
# ...

# %%
#Uncomment the line below to get csv file of above generated data
#change the name from Student_dataset.csv to filename.csv
#dataset = academic_data.to_csv('slider.csv', index = False)
# 'father_name','father_occupation','mother_name','mother_occupation','parent_income','pincode'

# %%
zipcode = []
data_latitude = {400001:'18.9385',400002:'18.9484',400003:'18.9532',400004:'18.958',400005:'18.9104',400006:'18.9541',400007:'18.9618',400008:'18.9671',400009:'18.9583',400010:'18.9702',400011:'18.981',400012:'18.9995',400013:'18.9982',400014:'19.0148',400015:'18.9961',400016:'19.0389',400017:'19.0456',400018:'18.9985',400019:'19.0269',400020:'18.9351',400021:'18.9256',400022:'19.0426',400023:'18.9321',400024:'19.0611',400025:'19.0158',400026:'18.9706',400027:'18.9793',400028:'19.0217',400029:'19.0797',400030:'19.0122',400031:'19.0133',400032:'18.929',400033:'18.9856',400034:'18.9724',400035:'18.9417',400036:'18.9625',400037:'19.0257',400038:'18.9377',400039:'18.9223',400040:'19.0636',400041:'19.0172',400042:'19.1338',400043:'19.0633',400044:'19.0633',400045:'19.0633',400046:'19.1367',400047:'19.1246',400048:'18.9104',400049:'19.1047',400050:'19.0552',400051:'19.0596',400052:'19.0717',400053:'19.1121',400054:'19.082',400055:'19.0804',400056:'19.1045',400057:'19.1007',400058:'19.1227',400059:'19.1119',400060:'19.1368',400061:'19.1427',400062:'19.1593',400063:'19.1648',400064:'19.1872',400065:'19.1556',400066:'19.2313',400067:'19.2072',400068:'19.2591',400069:'19.1178',400070:'19.0741',400071:'19.0521',400072:'19.1018',400073:'19.0718',400074:'19.029',400075:'19.0799',400076:'19.1239',400077:'19.0779',400078:'19.157',400079:'19.1025',400080:'19.1721',400081:'19.1661',400082:'19.1741',400083:'19.1166',400084:'19.0976',400085:'19.0438',400086:'19.0893',400087:'19.1391',400088:'19.0483',400089:'19.0685',400090:'19.1629',400091:'19.234',400092:'19.2327',400093:'19.1283',400094:'19.0359',400095:'19.1888',400096:'19.1267',400097:'19.1839',400098:'19.0718',400099:'19.0929',400100:'19.0929',400101:'19.2059',400102:'19.1419'}
longitude = []
data_longitude = {400001:'72.8363',400002:'72.8259',400003:'72.8353',400004:'72.8214',400005:'72.8198',400006:'72.8004',400007:'72.8134',400008:'72.8287',400009:'72.8389',400010:'72.846',400011:'72.8268',400012:'72.8397',400013:'72.8275',400014:'72.8455',400015:'72.8528',400016:'72.8421',400017:'72.8537',400018:'72.8174',400019:'72.8554',400020:'72.8264',400021:'72.8242',400022:'72.8638',400023:'72.8323',400024:'72.8792',400025:'72.8294',400026:'72.8095',400027:'72.8383',400028:'72.8375',400029:'72.8679',400030:'72.8219',400031:'72.8549',400032:'72.8301',400033:'72.8442',400034:'72.8148',400035:'72.7936',400036:'72.805',400037:'72.8697',400038:'72.839',400039:'72.8312',400040:'72.9228',400041:'72.9398',400042:'72.9384',400043:'72.9258',400044:'72.9258',400045:'72.9258',400046:'72.8109',400047:'72.8422',400048:'72.8198',400049:'72.8268',400050:'72.83',400051:'72.8553',400052:'72.8341',400053:'72.8611',400054:'72.8345',400055:'72.8469',400056:'72.8395',400057:'72.8485',400058:'72.8302',400059:'72.879',400060:'72.8579',400061:'72.8053',400062:'72.8427',400063:'72.8533',400064:'72.8407',400065:'72.885',400066:'72.8635',400067:'72.8348',400068:'72.8338',400069:'72.8737',400070:'72.8804',400071:'72.9007',400072:'72.8904',400073:'72.9168',400074:'72.8881',400075:'72.9174',400076:'72.9094',400077:'72.9056',400078:'72.9327',400079:'72.9254',400080:'72.9483',400081:'72.9646',400082:'72.9372',400083:'72.9374',400084:'72.9032',400085:'72.9121',400086:'72.9078',400087:'72.8956',400088:'72.9288',400089:'72.9003',400090:'72.8353',400091:'72.8399',400092:'72.7984',400093:'72.8677',400094:'72.9247',400095:'72.8197',400096:'72.8767',400097:'72.8584',400098:'72.8615',400099:'72.8654',400100:'72.8654',400101:'72.8661',400102:'72.8344'}
latitude = []
data_line = {400001:'harbour',400002:'western',400003:'central',400004:'western',400005:'western',400006:'western',400007:'western',400008:'central',400009:'harbour',400010:'harbour',400011:'central',400012:'central',400013:'western',400014:'central',400015:'central',400016:'harbour',400017:'central',400018:'western',400019:'central',400020:'western',400021:'western',400022:'central',400023:'harbour',400024:'harbour',400025:'western',400026:'western',400027:'central',400028:'central',400029:'western',400030:'western',400031:'harbour',400032:'western',400033:'harbour',400034:'western',400035:'western',400036:'western',400037:'harbour',400038:'harbour',400039:'western',400040:'central',400041:'western',400042:'central',400043:'harbour',400044:'harbour',400045:'harbour',400046:'central',400047:'western',400048:'western',400049:'western',400050:'western',400051:'harbour',400052:'harbour',400053:'western',400054:'western',400055:'western',400056:'western',400057:'western',400058:'western',400059:'western',400060:'western',400061:'western',400062:'harbour',400063:'harbour',400064:'harbour',400065:'harbour',400066:'western',400067:'western',400068:'western',400069:'western',400070:'harbour',400071:'harbour',400072:'central',400073:'central',400074:'harbour',400075:'central',400076:'central',400077:'central',400078:'central',400079:'central',400080:'central',400081:'central',400082:'central',400083:'central',400084:'central',400085:'harbour',400086:'central',400087:'central',400088:'harbour',400089:'harbour',400090:'western',400091:'western',400092:'western',400093:'western',400094:'harbour',400095:'western',400096:'western',400097:'western',400098:'central',400099:'western',400100:'western',400101:'harbour',400102:'western'}
line = []
hmap = []
for i in range(1440): 
    zipcode.append(np.random.randint(400001,400102))
    val1=zipcode[i]
    longitude.append(data_longitude[val1])
    val2=zipcode[i]
    latitude.append(data_latitude[val2])
    val3=zipcode[i]
    line.append(data_line[val3])
    hmap.append("0.1")
print(zipcode)
print(longitude)
print(latitude)
print(line)
# Out:
# [400074, 400037, 400042, 400066, 400058, 400081, 400008, 400058, 400066, 400086, 400101, 400050, 400071, 400008, 400064, 400036, 400059, 400013, 400005, 400017, 400007, 400043, 400058, 400006, 400074, 400064, 400082, 400010, 400094, 400038, 400028, 400033, 400015, 400063, 400042, 400069, 400078, 400069, 400026, 400035, 400021, 400057, 400088, 400014, 400051, 400013, 400050, 400008, 400084, 400074, 400090, 400034, 400101, 400088, 400078, 400033, 400061, 400057, 400005, 400076, 400009, 400003, 400093, 400098, 400023, 400034, 400054, 400093, 400018, 400026, 400006, 400028, 400005, 400069, 400091, 400039, 400075, 400081, 400071, 400022, 400029, 400087, 400048, 400019, 400085, 400022, 400050, 400095, 400066, 400077, 400063, 400020, 400006, 400040, 400081, 400064, 400040, 400030, 400049, 400065, 400083, 400066, 400028, 400054, 400021, 400093, 400093, 400084, 400087, 400028, 400069, 400062, 400035, 400001, 400026, 400003, 400050, 400047, 400080, 400078, 400014, 400041, 400053, 400054, 40010
# ...

# %%
location = pd.DataFrame(zip(zipcode,longitude,latitude,line,hmap),columns=["pincode","longitude","latitude","line","hmap"])
location
# Out:
#       pincode longitude latitude     line hmap
# 0      400074   72.8881   19.029  harbour  0.1
# 1      400037   72.8697  19.0257  harbour  0.1
# 2      400042   72.9384  19.1338  central  0.1
# 3      400066   72.8635  19.2313  western  0.1
# 4      400058   72.8302  19.1227  western  0.1
# ...       ...       ...      ...      ...  ...
# 1435   400100   72.8654  19.0929  western  0.1
# 1436   400046   72.8109  19.1367  central  0.1
# 1437   400039   72.8312  18.9223  western  0.1
# 1438   400015   72.8528  18.9961  central  0.1
# 1439   400094   72.9247  19.0359  harbour  0.1
#
# [1440 rows x 5 columns]

# %%
#dataset = location.to_csv('coords.csv', index = False)
